# %%
import pandas as pd
import numpy as np

# %%
from chefboost import Chefboost as chef
from chefboost.training import Training 
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.preprocessing import LabelEncoder 
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import pickle

# %%
dataset = pd.read_csv('dietdataset1.csv')

# %%
dataset = pd.DataFrame(data=dataset.iloc[:,0:10].values,columns = ['meal_name','carb','meat','vege','fruit', 'type','vegan','allergy','time'])
le = LabelEncoder()
dataset_encoded = dataset.iloc[:,0:10]
for i in dataset_encoded:
    dataset_encoded[i] = le.fit_transform(dataset_encoded[i])
dataset_encoded
# Out:
#       meal_name  carb  meat  vege  fruit  type  vegan  allergy  time
# 0            11     0     8    14      1     9      1        5     0
# 1            11     0     8    14      1     9      0        5     0
# 2            11     0     8    14      1     9      1        4     0
# 3            11     0     8    14      1     9      0        4     0
# 4            11     0     8    14      1     9      1        3     0
# ...         ...   ...   ...   ...    ...   ...    ...      ...   ...
# 5042          6    11     8    13      8     8      1        1     2
# 5043          6    11     8    13      8     8      1        4     2
# 5044          6    11     8    13      8     8      1        3     2
# 5045          6    11     8    13      8     8      1        2     2
# 5046          6    11     8    13      8     8      1        5     2
#
# [5047 rows x 9 columns]

# %%
dataset
# Out:
#                              meal_name   carb meat    vege    fruit
# 0                        Avocado Toast  bread  NaN     NaN  avocado  \
# 1                        Avocado Toast  bread  NaN     NaN  avocado
# 2                        Avocado Toast  bread  NaN     NaN  avocado
# 3                        Avocado Toast  bread  NaN     NaN  avocado
# 4                        Avocado Toast  bread  NaN     NaN  avocado
# ...                                ...    ...  ...     ...      ...
# 5042   Stir-Fried with tomato and peas    NaN  NaN  tomato      NaN
# 5043   Stir-Fried with tomato and peas    NaN  NaN  tomato      NaN
# 5044   Stir-Fried with tomato and peas    NaN  NaN  tomato      NaN
# 5045   Stir-Fried with tomato and peas    NaN  NaN  tomato      NaN
# 5046   Stir-Fried with tomato and peas    NaN  NaN  tomato      NaN
#
#             type vegan  allergy       time
# 0          toast   yes      NaN  Breakfast
# 1          toast    no      NaN  Breakfast
# 2          toast   yes  seafood  Breakfast
# 3          toast    no  seafood  Breakfast
# 4          toast   yes  lactose  Breakfast
# ...          ...   ...      ...        ...
# 5042  stir-fried   yes      egg      Lunch
# 5043  stir-fried   yes  seafood      Lunch
# 5044  stir-fried   yes  lactose      Lunch
# 5045  stir-fried   yes   gluten      Lunch
# 5046  stir-fried   yes      NaN      Lunch
#
# [5047 rows x 9 columns]

# %%
X = dataset_encoded.iloc[:,1:10]

y = dataset_encoded.iloc[:,0]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
model = DecisionTreeClassifier(criterion="gini")

model.fit(X_train.values, y_train)
# Out:
# DecisionTreeClassifier()

# %%
import random



def input_encode(entry, room):
    meal = dataset.values.tolist()
    meal_encode = dataset_encoded.values.tolist()
    lists = []
    encode = []
    
    for i in entry:
        found = False
        for j in meal:
            if i == j[room]:
                lists.append(j)
                found = True
                break
        if not found:
            print(f"Warning: '{i}' not found in dataset column {room}")
    
    for j in lists:
        encode.append(meal_encode[meal.index(j)][room])
        
    if not encode:
        raise ValueError(f"No encoding found for input: {entry} in room {room}")
        
    return encode

# Now, try calling your function as before
try:
    carb_encode = input_encode(carb_input, 1)[0]
    meat_encode = input_encode(meat_input, 2)[0]
    vege_encode = input_encode(vege_input, 3)[0]
    fruit_encode = input_encode(fruit_input, 4)[0]
    type_encode = input_encode(type_input, 5)[0]
    vegan_encode = input_encode(vegan_input, 6)[0]
    allergy_encode = input_encode(allergy_input, 7)[0]
    time_encode = input_encode(time_input, 8)[0]

    datainput = [carb_encode, meat_encode, vege_encode, fruit_encode, type_encode, vegan_encode, allergy_encode, time_encode]
    result = model.predict([datainput])
    prediction = input_decode(result, 0)
    print("Prediction: " + prediction[0])
except ValueError as e:
    print("Error:", e)
# Out:
# Warning: 'None' not found in dataset column 1
# Error: No encoding found for input: ['None'] in room 1

# %%
accuracy_score(model.predict(X_test.values),y_test)
# Out:
# 0.831023102310231

# %%
from sklearn.metrics import average_precision_score

# Reshape predictions to 2D if necessary
predictions = model.predict(X_test.values).reshape(-1, 1)

# Calculate the average precision score
average_precision = average_precision_score(y_test, predictions, average='macro', sample_weight=None)
print("Average Precision Score:", average_precision)
# Out:
# Average Precision Score: 0.006090298160516211

# %%
f1_score(y_test, model.predict(X_test.values),average='weighted')
# Out:
# 0.8316729288490906

# %%
recall_score(y_test, model.predict(X_test.values),average='weighted')
# Out:
# C:\Users\User\anaconda3\envs\Project\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 0.831023102310231

# %%
y_true = y_test
y_pred = model.predict(X_test.values)
classification_report(y_true, y_pred, labels=None, target_names=None, sample_weight=None, digits=2, output_dict=True, zero_division=0)
# Out:
# {'0': {'precision': 0.21428571428571427,
#   'recall': 0.23076923076923078,
#   'f1-score': 0.2222222222222222,
#   'support': 13.0},
#  '1': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 15.0},
#  '2': {'precision': 0.625,
#   'recall': 0.5555555555555556,
#   'f1-score': 0.5882352941176471,
#   'support': 9.0},
#  '3': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '4': {'precision': 0.5333333333333333,
#   'recall': 0.5333333333333333,
#   'f1-score': 0.5333333333333333,
#   'support': 15.0},
#  '5': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 21.0},
#  '6': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 13.0},
#  '7': {'precision': 0.3333333333333333,
#   'recall': 1.0,
#   'f1-score': 0.5,
#   'support': 2.0},
#  '8': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '9': {'precision': 0.4782608695652174,
#   'recall': 0.6875,
#   'f1-score': 0.5641025641025641,
#   'support': 16.0},
#  '10': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '11': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '12': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '13': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '14': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '15': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3.0},
#  '16': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8.0},
#  '17': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8.0},
#  '18': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10.0},
#  '19': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '20': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10.0},
#  '21': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2.0},
#  '22': {'precision': 0.2,
#   'recall': 0.2857142857142857,
#   'f1-score': 0.23529411764705882,
#   'support': 7.0},
#  '23': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9.0},
#  '24': {'precision': 0.75,
#   'recall': 0.42857142857142855,
#   'f1-score': 0.5454545454545454,
#   'support': 7.0},
#  '25': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '26': {'precision': 0.42857142857142855,
#   'recall': 0.42857142857142855,
#   'f1-score': 0.42857142857142855,
#   'support': 7.0},
#  '27': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9.0},
#  '28': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8.0},
#  '29': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9.0},
#  '30': {'precision': 0.6, 'recall': 0.9, 'f1-score': 0.72, 'support': 10.0},
#  '31': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2.0},
#  '32': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '33': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8.0},
#  '34': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '35': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2.0},
#  '36': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '37': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '38': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '40': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1.0},
#  '41': {'precision': 0.225,
#   'recall': 0.6428571428571429,
#   'f1-score': 0.3333333333333333,
#   'support': 14.0},
#  '42': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2.0},
#  '43': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '44': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '45': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 11.0},
#  '46': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '48': {'precision': 0.3333333333333333,
#   'recall': 0.5,
#   'f1-score': 0.4,
#   'support': 6.0},
#  '49': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 11.0},
#  '50': {'precision': 0.6,
#   'recall': 0.5,
#   'f1-score': 0.5454545454545454,
#   'support': 6.0},
#  '51': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '52': {'precision': 0.8888888888888888,
#   'recall': 0.7272727272727273,
#   'f1-score': 0.8,
#   'support': 11.0},
#  '53': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '54': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '55': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '56': {'precision': 0.7142857142857143,
#   'recall': 0.7142857142857143,
#   'f1-score': 0.7142857142857143,
#   'support': 7.0},
#  '57': {'precision': 0.68,
#   'recall': 0.7083333333333334,
#   'f1-score': 0.6938775510204082,
#   'support': 24.0},
#  '58': {'precision': 0.7333333333333333,
#   'recall': 0.4583333333333333,
#   'f1-score': 0.5641025641025641,
#   'support': 24.0},
#  '59': {'precision': 0.3333333333333333,
#   'recall': 0.3157894736842105,
#   'f1-score': 0.32432432432432434,
#   'support': 19.0},
#  '60': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9.0},
#  '61': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '62': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '63': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '65': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '66': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '67': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '68': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '69': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '70': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '71': {'precision': 0.3333333333333333,
#   'recall': 0.25,
#   'f1-score': 0.2857142857142857,
#   'support': 4.0},
#  '72': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '73': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '74': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '75': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '76': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2.0},
#  '77': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '78': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2.0},
#  '79': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '80': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '81': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '82': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '83': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '84': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9.0},
#  '85': {'precision': 0.8421052631578947,
#   'recall': 0.8,
#   'f1-score': 0.8205128205128205,
#   'support': 20.0},
#  '86': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2.0},
#  '87': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9.0},
#  '88': {'precision': 0.6470588235294118,
#   'recall': 0.6875,
#   'f1-score': 0.6666666666666666,
#   'support': 16.0},
#  '89': {'precision': 0.6666666666666666,
#   'recall': 0.3,
#   'f1-score': 0.41379310344827586,
#   'support': 20.0},
#  '90': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '91': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 11.0},
#  '92': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '93': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8.0},
#  '94': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 15.0},
#  '95': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '96': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9.0},
#  '97': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '98': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '99': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '100': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1.0},
#  '101': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '102': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '103': {'precision': 0.3333333333333333,
#   'recall': 0.5,
#   'f1-score': 0.4,
#   'support': 4.0},
#  '104': {'precision': 1.0,
#   'recall': 0.4,
#   'f1-score': 0.5714285714285714,
#   'support': 5.0},
#  '105': {'precision': 0.3333333333333333,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.3333333333333333,
#   'support': 6.0},
#  '106': {'precision': 1.0, 'recall': 0.25, 'f1-score': 0.4, 'support': 4.0},
#  '107': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 2.0},
#  '108': {'precision': 0.5,
#   'recall': 0.25,
#   'f1-score': 0.3333333333333333,
#   'support': 4.0},
#  '109': {'precision': 0.5384615384615384,
#   'recall': 0.4666666666666667,
#   'f1-score': 0.5,
#   'support': 15.0},
#  '110': {'precision': 0.7777777777777778,
#   'recall': 0.5384615384615384,
#   'f1-score': 0.6363636363636364,
#   'support': 13.0},
#  '111': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '112': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '113': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '114': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '115': {'precision': 0.25,
#   'recall': 0.125,
#   'f1-score': 0.16666666666666666,
#   'support': 8.0},
#  '116': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9.0},
#  '117': {'precision': 0.4,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.5,
#   'support': 3.0},
#  '118': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '119': {'precision': 0.5555555555555556,
#   'recall': 0.7142857142857143,
#   'f1-score': 0.625,
#   'support': 7.0},
#  '120': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '121': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '122': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 11.0},
#  '123': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8.0},
#  '124': {'precision': 1.0,
#   'recall': 0.5,
#   'f1-score': 0.6666666666666666,
#   'support': 10.0},
#  '125': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '126': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2.0},
#  '127': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '128': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '129': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '130': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '131': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '132': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10.0},
#  '133': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10.0},
#  '134': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '135': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 13.0},
#  '136': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 15.0},
#  '137': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 26.0},
#  '138': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '139': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2.0},
#  '140': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '141': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '142': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '143': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2.0},
#  '144': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '145': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '146': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '147': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '148': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 12.0},
#  '149': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1.0},
#  '150': {'precision': 0.3333333333333333,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.3333333333333333,
#   'support': 3.0},
#  '151': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '152': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 1.0},
#  '153': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '154': {'precision': 0.8,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.7272727272727273,
#   'support': 6.0},
#  '155': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8.0},
#  '156': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1.0},
#  '157': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8.0},
#  '158': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '159': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2.0},
#  '160': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2.0},
#  '161': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0.0},
#  '162': {'precision': 0.16666666666666666,
#   'recall': 1.0,
#   'f1-score': 0.2857142857142857,
#   'support': 1.0},
#  '163': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9.0},
#  '164': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '165': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 13.0},
#  '166': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 12.0},
#  '167': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '168': {'precision': 0.25,
#   'recall': 0.2857142857142857,
#   'f1-score': 0.26666666666666666,
#   'support': 7.0},
#  '169': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2.0},
#  '170': {'precision': 0.3333333333333333,
#   'recall': 0.2,
#   'f1-score': 0.25,
#   'support': 5.0},
#  '171': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '172': {'precision': 0.5714285714285714,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.6153846153846154,
#   'support': 6.0},
#  '173': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8.0},
#  '174': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '175': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '176': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 6.0},
#  '177': {'precision': 0.3076923076923077,
#   'recall': 0.2857142857142857,
#   'f1-score': 0.2962962962962963,
#   'support': 14.0},
#  '178': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9.0},
#  '179': {'precision': 0.625,
#   'recall': 0.5555555555555556,
#   'f1-score': 0.5882352941176471,
#   'support': 9.0},
#  '180': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '181': {'precision': 0.36363636363636365,
#   'recall': 0.4444444444444444,
#   'f1-score': 0.4,
#   'support': 9.0},
#  '182': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 13.0},
#  '183': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 11.0},
#  '184': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4.0},
#  '185': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '186': {'precision': 0.6666666666666666,
#   'recall': 0.25,
#   'f1-score': 0.36363636363636365,
#   'support': 8.0},
#  '187': {'precision': 0.6666666666666666,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.6666666666666666,
#   'support': 6.0},
#  '188': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10.0},
#  '189': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '190': {'precision': 0.3333333333333333,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.4444444444444444,
#   'support': 3.0},
#  '191': {'precision': 0.625,
#   'recall': 0.7142857142857143,
#   'f1-score': 0.6666666666666666,
#   'support': 7.0},
#  '192': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7.0},
#  '193': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10.0},
#  '194': {'precision': 0.2,
#   'recall': 0.5,
#   'f1-score': 0.2857142857142857,
#   'support': 2.0},
#  '195': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 11.0},
#  '196': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9.0},
#  '197': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2.0},
#  '198': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4.0},
#  '199': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '200': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1.0},
#  '201': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3.0},
#  '202': {'precision': 0.7142857142857143,
#   'recall': 0.7142857142857143,
#   'f1-score': 0.7142857142857143,
#   'support': 7.0},
#  '203': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '204': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '205': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '206': {'precision': 0.7142857142857143,
#   'recall': 0.625,
#   'f1-score': 0.6666666666666666,
#   'support': 8.0},
#  '207': {'precision': 0.8333333333333334,
#   'recall': 0.5555555555555556,
#   'f1-score': 0.6666666666666666,
#   'support': 9.0},
#  '208': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9.0},
#  '210': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 12.0},
#  '211': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2.0},
#  '212': {'precision': 0.2222222222222222,
#   'recall': 0.5,
#   'f1-score': 0.3076923076923077,
#   'support': 4.0},
#  '213': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 13.0},
#  '214': {'precision': 1.0,
#   'recall': 0.4444444444444444,
#   'f1-score': 0.6153846153846154,
#   'support': 9.0},
#  '215': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1.0},
#  '216': {'precision': 0.5, 'recall': 0.5, 'f1-score': 0.5, 'support': 4.0},
#  '217': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8.0},
#  '218': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5.0},
#  '219': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6.0},
#  '220': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 20.0},
#  '221': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 12.0},
#  '222': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3.0},
#  '223': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4.0},
#  '224': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2.0},
#  '225': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4.0},
#  '226': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2.0},
#  'accuracy': 0.831023102310231,
#  'macro avg': {'precision': 0.8344191440999852,
#   'recall': 0.8339632327654513,
#   'f1-score': 0.82522928956075,
#   'support': 1515.0},
#  'weighted avg': {'precision': 0.8477633450639732,
#   'recall': 0.831023102310231,
#   'f1-score': 0.8316729288490906,
#   'support': 1515.0}}

# %%
pickle.dump(model, open('model1', 'wb'))
