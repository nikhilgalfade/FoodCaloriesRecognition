# %%
import pandas as pd
import numpy as np

# %%
from chefboost import Chefboost as chef
from chefboost.training import Training 
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.preprocessing import LabelEncoder 
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import pickle
# Out:
# C:\Users\User\anaconda3\envs\Project\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataset = pd.read_csv('dietdataset.csv')

# %%
dataset = pd.DataFrame(data=dataset.iloc[:,0:10].values,columns = ['meal_name','carb','meat','vege','fruit', 'type','vegan','allergy','time'])
le = LabelEncoder()
dataset_encoded = dataset.iloc[:,0:10]
for i in dataset_encoded:
    dataset_encoded[i] = le.fit_transform(dataset_encoded[i])
dataset_encoded
# Out:
#       meal_name  carb  meat  vege  fruit  type  vegan  allergy  time
# 0            11     0     8    14      1     9      1        5     0
# 1            11     0     8    14      1     9      0        5     0
# 2            11     0     8    14      1     9      1        4     0
# 3            11     0     8    14      1     9      0        4     0
# 4            11     0     8    14      1     9      1        3     0
# ...         ...   ...   ...   ...    ...   ...    ...      ...   ...
# 5042          6    11     8    13      8     8      1        1     2
# 5043          6    11     8    13      8     8      1        4     2
# 5044          6    11     8    13      8     8      1        3     2
# 5045          6    11     8    13      8     8      1        2     2
# 5046          6    11     8    13      8     8      1        5     2
#
# [5047 rows x 9 columns]

# %%
dataset
# Out:
#                              meal_name   carb meat    vege    fruit
# 0                        Avocado Toast  bread  NaN     NaN  avocado  \
# 1                        Avocado Toast  bread  NaN     NaN  avocado
# 2                        Avocado Toast  bread  NaN     NaN  avocado
# 3                        Avocado Toast  bread  NaN     NaN  avocado
# 4                        Avocado Toast  bread  NaN     NaN  avocado
# ...                                ...    ...  ...     ...      ...
# 5042   Stir-Fried with tomato and peas    NaN  NaN  tomato      NaN
# 5043   Stir-Fried with tomato and peas    NaN  NaN  tomato      NaN
# 5044   Stir-Fried with tomato and peas    NaN  NaN  tomato      NaN
# 5045   Stir-Fried with tomato and peas    NaN  NaN  tomato      NaN
# 5046   Stir-Fried with tomato and peas    NaN  NaN  tomato      NaN
#
#             type vegan  allergy       time
# 0          toast   yes      NaN  Breakfast
# 1          toast    no      NaN  Breakfast
# 2          toast   yes  seafood  Breakfast
# 3          toast    no  seafood  Breakfast
# 4          toast   yes  lactose  Breakfast
# ...          ...   ...      ...        ...
# 5042  stir-fried   yes      egg      Lunch
# 5043  stir-fried   yes  seafood      Lunch
# 5044  stir-fried   yes  lactose      Lunch
# 5045  stir-fried   yes   gluten      Lunch
# 5046  stir-fried   yes      NaN      Lunch
#
# [5047 rows x 9 columns]

# %%
X = dataset_encoded.iloc[:,1:10]

y = dataset_encoded.iloc[:,0]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
model = DecisionTreeClassifier(criterion="gini")

model.fit(X_train.values, y_train)
# Out:
# DecisionTreeClassifier()

# %%
import random



def input_encode(entry,room): 
    meal = dataset.values.tolist()
    meal_encode = dataset_encoded.values.tolist()
    lists = []
    encode = []   
    for i in entry:
        for j in meal:
            if i==j[room]:
                lists.append(j)
                break
                 
    for j in lists: 
        encode.append(meal_encode[meal.index(j)][room])
        
    return encode
#         return meal_encode[meal.index(j)][room]

def input_decode(entry,room): 
    meal = dataset.values.tolist()
    meal_encode = dataset_encoded.values.tolist()
    lists = []
    decode = []   
    for i in entry:
        for j in meal_encode:
            if i==j[room]:
                lists.append(j)
                break
                 
    for j in lists: 
        decode.append(meal[meal_encode.index(j)][room])
        
    return decode

carb_input = ['None']
meat_input = ['None']
vege_input = ['carrot']
fruit_input = ['None']
type_input = ['stir-fried']
vegan_input = ['yes']
allergy_input = ['None']
time_input = ['Dinner']

carb_encode = input_encode(carb_input,1)[0]
meat_encode = input_encode(meat_input,2)[0]
vege_encode = input_encode(vege_input,3)[0]
fruit_encode = input_encode(fruit_input,4)[0]
type_encode = input_encode(type_input,5)[0]
vegan_encode = input_encode(vegan_input,6)[0]
allergy_encode = input_encode(allergy_input,7)[0]
time_encode = input_encode(time_input,8)[0]

output = []

        
datainput = [carb_encode,meat_encode,vege_encode,fruit_encode,type_encode,vegan_encode,allergy_encode,time_encode]

result = model.predict([datainput])
    
prediction = input_decode(result,0)
    
print("Prediction: "+prediction[0])  
print(carb_input,meat_input,vege_input,fruit_input,type_input,vegan_input,allergy_input,time_input)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 47
#      44 allergy_input = ['None']
#      45 time_input = ['Dinner']
# ---> 47 carb_encode = input_encode(carb_input,1)[0]
#      48 meat_encode = input_encode(meat_input,2)[0]
#      49 vege_encode = input_encode(vege_input,3)[0]
#
# IndexError: list index out of range

# %%
accuracy_score(model.predict(X_test.values),y_test)
# Out:
# 0.8359046283309958

# %%
average_precision_score(y_test,model.predict(X_test.values),average='macro',pos_label=2, sample_weight=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [102], in <module>
# ----> 1 average_precision_score(y_test,model.predict(X_test.values),average='macro',pos_label=2, sample_weight=None)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_ranking.py:232, in average_precision_score(y_true, y_score, average, pos_label, sample_weight)
#     225         raise ValueError(
#     226             f"pos_label={pos_label} is not a valid label. It should be "
#     227             f"one of {present_labels}"
#     228         )
#     229 average_precision = partial(
#     230     _binary_uninterpolated_average_precision, pos_label=pos_label
#     231 )
# --> 232 return _average_binary_score(
#     233     average_precision, y_true, y_score, average, sample_weight=sample_weight
#     234 )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_base.py:72, in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      70 y_type = type_of_target(y_true)
#      71 if y_type not in ("binary", "multilabel-indicator"):
# ---> 72     raise ValueError("{0} format is not supported".format(y_type))
#      74 if y_type == "binary":
#      75     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#
# ValueError: multiclass format is not supported

# %%
f1_score(y_test, model.predict(X_test.values),average='weighted')
# Out:
# 0.8433096725294085

# %%
recall_score(y_test, model.predict(X_test.values),average='weighted')
# Out:
# 0.8415147265077139

# %%
y_true = y_test
y_pred = model.predict(X_test.values)
classification_report(y_true, y_pred, labels=None, target_names=None, sample_weight=None, digits=2, output_dict=True, zero_division=0)
# Out:
# {'0': {'precision': 0.3333333333333333,
#   'recall': 0.16666666666666666,
#   'f1-score': 0.2222222222222222,
#   'support': 6},
#  '1': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '2': {'precision': 0.5333333333333333,
#   'recall': 0.6153846153846154,
#   'f1-score': 0.5714285714285715,
#   'support': 13},
#  '3': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '4': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 11},
#  '5': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '6': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '7': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '8': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#  '9': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '10': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '11': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '12': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#  '13': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '14': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9},
#  '15': {'precision': 0.16666666666666666,
#   'recall': 0.1,
#   'f1-score': 0.125,
#   'support': 10},
#  '16': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10},
#  '17': {'precision': 0.25, 'recall': 0.25, 'f1-score': 0.25, 'support': 4},
#  '18': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '19': {'precision': 0.5, 'recall': 0.75, 'f1-score': 0.6, 'support': 8},
#  '20': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#  '21': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '22': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '23': {'precision': 0.5555555555555556,
#   'recall': 0.7142857142857143,
#   'f1-score': 0.6250000000000001,
#   'support': 7},
#  '24': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#  '25': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '26': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '27': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '28': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '29': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '30': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '32': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#  '33': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '34': {'precision': 0.3225806451612903,
#   'recall': 0.47619047619047616,
#   'f1-score': 0.3846153846153846,
#   'support': 21},
#  '35': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '36': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '37': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#  '38': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 14},
#  '39': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2},
#  '40': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#  '41': {'precision': 0.4,
#   'recall': 0.5,
#   'f1-score': 0.4444444444444445,
#   'support': 8},
#  '42': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '43': {'precision': 0.7,
#   'recall': 0.7777777777777778,
#   'f1-score': 0.7368421052631577,
#   'support': 9},
#  '44': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#  '45': {'precision': 0.6666666666666666,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.4444444444444444,
#   'support': 6},
#  '46': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10},
#  '47': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '48': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '49': {'precision': 0.8,
#   'recall': 0.5,
#   'f1-score': 0.6153846153846154,
#   'support': 8},
#  '50': {'precision': 0.5714285714285714,
#   'recall': 0.8,
#   'f1-score': 0.6666666666666666,
#   'support': 20},
#  '51': {'precision': 0.5714285714285714,
#   'recall': 0.5454545454545454,
#   'f1-score': 0.5581395348837208,
#   'support': 22},
#  '52': {'precision': 0.7333333333333333,
#   'recall': 0.39285714285714285,
#   'f1-score': 0.5116279069767441,
#   'support': 28},
#  '53': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 14},
#  '54': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#  '55': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#  '56': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '57': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '58': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '59': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '60': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '61': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '62': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '63': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '64': {'precision': 0.25, 'recall': 0.25, 'f1-score': 0.25, 'support': 4},
#  '65': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '66': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '67': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#  '68': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#  '69': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '70': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '71': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '72': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '73': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2},
#  '74': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '75': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2},
#  '76': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '77': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '78': {'precision': 0.8421052631578947,
#   'recall': 1.0,
#   'f1-score': 0.9142857142857143,
#   'support': 16},
#  '79': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '80': {'precision': 0.7272727272727273,
#   'recall': 0.9230769230769231,
#   'f1-score': 0.8135593220338984,
#   'support': 26},
#  '81': {'precision': 0.6363636363636364,
#   'recall': 0.4375,
#   'f1-score': 0.5185185185185185,
#   'support': 16},
#  '82': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9},
#  '83': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9},
#  '84': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#  '85': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '86': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '87': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 24},
#  '88': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10},
#  '89': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '90': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#  '91': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '92': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '93': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '94': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9},
#  '95': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#  '96': {'precision': 0.6,
#   'recall': 0.75,
#   'f1-score': 0.6666666666666665,
#   'support': 4},
#  '97': {'precision': 0.6,
#   'recall': 0.75,
#   'f1-score': 0.6666666666666665,
#   'support': 4},
#  '98': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2},
#  '99': {'precision': 0.4,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.5,
#   'support': 3},
#  '100': {'precision': 0.6666666666666666,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.6666666666666666,
#   'support': 6},
#  '101': {'precision': 1.0,
#   'recall': 0.5,
#   'f1-score': 0.6666666666666666,
#   'support': 4},
#  '102': {'precision': 0.9,
#   'recall': 0.6,
#   'f1-score': 0.7200000000000001,
#   'support': 15},
#  '103': {'precision': 1.0,
#   'recall': 0.45454545454545453,
#   'f1-score': 0.625,
#   'support': 11},
#  '104': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '105': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9},
#  '106': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#  '107': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 13},
#  '108': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 8},
#  '109': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9},
#  '110': {'precision': 0.6666666666666666,
#   'recall': 0.8571428571428571,
#   'f1-score': 0.75,
#   'support': 7},
#  '111': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#  '112': {'precision': 0.375, 'recall': 0.75, 'f1-score': 0.5, 'support': 4},
#  '113': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '114': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2},
#  '115': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10},
#  '116': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 11},
#  '117': {'precision': 0.75,
#   'recall': 0.6,
#   'f1-score': 0.6666666666666665,
#   'support': 10},
#  '118': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '119': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '120': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2},
#  '121': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2},
#  '122': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#  '124': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '125': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '126': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 12},
#  '127': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '128': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '129': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 16},
#  '130': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 24},
#  '131': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '132': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '133': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '134': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#  '135': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2},
#  '136': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '138': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2},
#  '139': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '140': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 11},
#  '141': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#  '142': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '143': {'precision': 0.2,
#   'recall': 0.5,
#   'f1-score': 0.28571428571428575,
#   'support': 4},
#  '144': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '145': {'precision': 1.0,
#   'recall': 0.5,
#   'f1-score': 0.6666666666666666,
#   'support': 8},
#  '146': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '147': {'precision': 0.7142857142857143,
#   'recall': 0.5555555555555556,
#   'f1-score': 0.6250000000000001,
#   'support': 9},
#  '148': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '149': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '150': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '151': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '152': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2},
#  '154': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#  '155': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2},
#  '156': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#  '157': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2},
#  '158': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '159': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '160': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '161': {'precision': 0.25,
#   'recall': 0.5,
#   'f1-score': 0.3333333333333333,
#   'support': 4},
#  '162': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '163': {'precision': 1.0,
#   'recall': 0.2,
#   'f1-score': 0.33333333333333337,
#   'support': 5},
#  '164': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '165': {'precision': 0.3333333333333333,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.3333333333333333,
#   'support': 3},
#  '166': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '167': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '168': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '169': {'precision': 0.2,
#   'recall': 0.5,
#   'f1-score': 0.28571428571428575,
#   'support': 2},
#  '170': {'precision': 0.35714285714285715,
#   'recall': 0.4166666666666667,
#   'f1-score': 0.3846153846153846,
#   'support': 12},
#  '171': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '172': {'precision': 0.6153846153846154,
#   'recall': 0.7272727272727273,
#   'f1-score': 0.6666666666666667,
#   'support': 11},
#  '173': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '174': {'precision': 0.8181818181818182,
#   'recall': 0.6,
#   'f1-score': 0.6923076923076923,
#   'support': 15},
#  '175': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 12},
#  '176': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 11},
#  '177': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#  '178': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '179': {'precision': 0.6,
#   'recall': 0.42857142857142855,
#   'f1-score': 0.5,
#   'support': 7},
#  '180': {'precision': 0.42857142857142855,
#   'recall': 0.75,
#   'f1-score': 0.5454545454545454,
#   'support': 4},
#  '181': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '182': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#  '183': {'precision': 0.8,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.7272727272727272,
#   'support': 6},
#  '184': {'precision': 0.5,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.5714285714285715,
#   'support': 6},
#  '185': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#  '186': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10},
#  '187': {'precision': 1.0,
#   'recall': 0.75,
#   'f1-score': 0.8571428571428571,
#   'support': 4},
#  '188': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '189': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2},
#  '190': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9},
#  '191': {'precision': 0.25,
#   'recall': 0.125,
#   'f1-score': 0.16666666666666666,
#   'support': 8},
#  '192': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '193': {'precision': 0.5, 'recall': 0.5, 'f1-score': 0.5, 'support': 4},
#  '194': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '195': {'precision': 0.4444444444444444,
#   'recall': 0.8,
#   'f1-score': 0.5714285714285714,
#   'support': 5},
#  '196': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '197': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '198': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10},
#  '199': {'precision': 0.5,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.4,
#   'support': 6},
#  '200': {'precision': 0.8888888888888888,
#   'recall': 1.0,
#   'f1-score': 0.9411764705882353,
#   'support': 8},
#  '201': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '202': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10},
#  '203': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#  '204': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#  '205': {'precision': 0.3333333333333333,
#   'recall': 0.3,
#   'f1-score': 0.3157894736842105,
#   'support': 10},
#  '206': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10},
#  '207': {'precision': 0.75,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.7058823529411765,
#   'support': 9},
#  '208': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '209': {'precision': 0.5454545454545454,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.6,
#   'support': 9},
#  '210': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10},
#  '211': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '212': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#  '213': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 18},
#  '214': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 16},
#  '215': {'precision': 0.25, 'recall': 1.0, 'f1-score': 0.4, 'support': 1},
#  '216': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2},
#  '217': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#  '218': {'precision': 0.2857142857142857,
#   'recall': 0.5,
#   'f1-score': 0.36363636363636365,
#   'support': 4},
#  '219': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#  'accuracy': 0.8429172510518934,
#  'macro avg': {'precision': 0.8522367449156026,
#   'recall': 0.8523793914418915,
#   'f1-score': 0.8446901683631034,
#   'support': 1426},
#  'weighted avg': {'precision': 0.8526064655875566,
#   'recall': 0.8429172510518934,
#   'f1-score': 0.8400712386385871,
#   'support': 1426}}

# %%
pickle.dump(model, open('model', 'wb'))
